# %%
import pandas as pd

# %%
# Lue Excel- tai CSV-tiedosto
df = pd.read_csv("ice-cream-europe.csv")  # tai .csv riippuen muodosta
df.head(20)
# Out:
#    Data extracted on 12/05/2025 19:54:39 from [ESTAT]  \
# 0                                           Dataset:
# 1                                      Last updated:
# 2                                                 NaN
# 3                                           Frequency
# 4                                                 NaN
# 5                                                TIME
# 6                                 INDICATORS (Labels)
# 7                                    PRCCODE (Labels)
# 8   Ice cream and other edible ice (including sher...
# 9   Ice cream and other edible ice (including sher...
# 10  Ice cream and other edible ice (including sher...
# 11  Ice cream and other edible ice (including sher...
# 12  Ice cream and other edible ice (including sher...
# 13  Ice cream and other edible ice (including sher...
# 14  Ice cream and other edible ice (including sher...
# 15  Ice cream and other edible ice (including sher...
# ...

# %% [markdown]
# df = pd.read_csv("ice-cream-europe.csv", header=5)
# df.head()

# %%
df = pd.read_csv("ice-cream-europe.csv", header=5)
df.head()
# Out:
#                                           Unnamed: 0     Unnamed: 1  \
# 0                                               TIME            NaN
# 1                                INDICATORS (Labels)            NaN
# 2                                   PRCCODE (Labels)  DECL (Labels)
# 3  Ice cream and other edible ice (including sher...         France
# 4  Ice cream and other edible ice (including sher...    Netherlands
#
#    Unnamed: 2   Unnamed: 3   Unnamed: 4   Unnamed: 5  Unnamed: 6   Unnamed: 7  \
# 0        2021          NaN          NaN          NaN        2022          NaN
# 1  OWNPRODQNT   OWNPRODVAL      PRODQNT      PRODVAL  OWNPRODQNT   OWNPRODVAL
# 2           4          NaN          NaN          NaN         NaN          NaN
# 3           :            :  530,984,341  976,929,000           :            :
# 4  62,734,000  142,370,000            :            :  64,167,000  157,913,000
#
#     Unnamed: 8     Unnamed: 9
# 0          NaN            NaN
# ...

# %%
# Lue tiedosto, ottaen oikea header-rivi (rivinumero 0 kuvassa)
df = pd.read_csv("ice-cream-europe.csv", header=0)

# Jos ensimmäinen näkyvä rivi (kuvassa rivi 0) ei ole oikeasti tiedoston ensimmäinen rivi,
# vaan header on kolmannella rivillä (esim. rivillä 3 tiedostossa), käytä:
df = pd.read_csv("ice-cream-europe.csv", header=6)
df.head()
# Out:
#                                                 TIME     Unnamed: 1  \
# 0                                INDICATORS (Labels)            NaN
# 1                                   PRCCODE (Labels)  DECL (Labels)
# 2  Ice cream and other edible ice (including sher...         France
# 3  Ice cream and other edible ice (including sher...    Netherlands
# 4  Ice cream and other edible ice (including sher...        Germany
#
#          2021   Unnamed: 3   Unnamed: 4   Unnamed: 5         2022  \
# 0  OWNPRODQNT   OWNPRODVAL      PRODQNT      PRODVAL   OWNPRODQNT
# 1           4          NaN          NaN          NaN          NaN
# 2           :            :  530,984,341  976,929,000            :
# 3  62,734,000  142,370,000            :            :   64,167,000
# 4           :            :  613,966,539  874,943,000  394,896,126
#
#     Unnamed: 7   Unnamed: 8     Unnamed: 9
# 0   OWNPRODVAL      PRODQNT        PRODVAL
# 1          NaN          NaN            NaN
# ...

# %%
df.columns = df.iloc[0]
df = df[1:]  # Poista ensimmäinen rivi, joka nyt on headerina
df.head()
# Out:
# 1                                   PRCCODE (Labels) DECL (Labels)  \
# 2  Ice cream and other edible ice (including sher...        France
# 3  Ice cream and other edible ice (including sher...   Netherlands
# 4  Ice cream and other edible ice (including sher...       Germany
# 5  Ice cream and other edible ice (including sher...         Italy
# 6  Ice cream and other edible ice (including sher...       Ireland
#
# 1            4          NaN          NaN          NaN          NaN  \
# 2            :            :  530,984,341  976,929,000            :
# 3   62,734,000  142,370,000            :            :   64,167,000
# 4            :            :  613,966,539  874,943,000  394,896,126
# 5  275,850,691  736,904,000  381,113,331  802,744,000  449,757,300
# 6            :            :            :            :            :
#
# 1            NaN          NaN            NaN
# 2              :  587,701,447  1,140,617,000
# 3    157,913,000            :              :
# ...
